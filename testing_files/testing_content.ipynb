# %%
# %run contentGeneration.py

# %%
# Test 
test_keyword = "Conversion Roadmap"
test_link = "https://www.invespcro.com/blog/creating-a-conversion-roadmap-how-to-prioritize-conversion-problems-on-your-website/"

# %%
run(test_link,test_keyword)
get_all_resutls()

# %%
from content import ArticleGenerator

# %%
generator = ArticleGenerator()

keyword = "website conversions"
link = "https://www.gartner.com/en/digital-markets/insights/how-to-increase-conversion-rates"
generator.run(link,keyword)

generator.get_all_results()
# Out:
# Article:
# # Boost Your Business with Effective Website Conversions: Strategies and Analysis
#
# ## Introduction
#
# In today's digital age, having a strong online presence is crucial for the success of any business. One of the key metrics that determines the effectiveness of your online strategy is website conversions. In this article, we will explore the strategies and analysis techniques that can help you boost your business by improving your website conversions.
#
# ### Importance of Conversion Rates in Digital Marketing
#
# Conversion rates play a vital role in digital marketing. They measure the percentage of website visitors who take a desired action, such as making a purchase, signing up for a newsletter, or filling out a contact form. By increasing your conversion rates, you can maximize the return on investment (ROI) of your marketing efforts and drive more revenue for your business.
#
# ### Definition of Conversion Rates
#
# ...
