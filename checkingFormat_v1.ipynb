# %%
from contentGeneration import *
import time
import openai
from openai import OpenAI
import os
from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())

os.environ['OPENAI_API_KEY'] = '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'
openai.api_key  = os.getenv('OPENAI_API_KEY')

# %%
# set up the function 
client = OpenAI(api_key=os.environ.get("OPENAI_API_KEY"),)

# normal prompt generation 
def get_completion(prompt, model="gpt-3.5-turbo"):
    messages = [{"role": "user", "content": prompt}]
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=0
    )
    return response.choices[0].message.content

# %%
# Test 
test_keyword = "Conversion Roadmap"
test_link = "https://www.invespcro.com/blog/creating-a-conversion-roadmap-how-to-prioritize-conversion-problems-on-your-website/"

# %%
run(test_link,test_keyword)
artilce = get_article()
meta = get_metadata()
picture_link = get_picture_link()

# %%
print(artilce)
print()
print(picture_link)
print()
print(meta)
# Out:
# Creating a Roadmap to Improve Your Conversion Rates: A Step-by-Step Guide
#
# Introduction
#
# Are you looking to boost your conversion rates and improve the performance of your online store? In this article, we will guide you through the process of creating a conversion roadmap. By following these steps, you can identify and address common conversion problems, prioritize your efforts, and develop strategies to optimize your store's performance.
#
# Understanding Conversion Problems
#
# Conversion problems refer to the issues that prevent visitors from taking the desired action on your website, such as making a purchase or submitting a form. By understanding these problems, you can effectively address them and improve your conversion rates. Some common conversion problems include:
#
# 1. High bounce rates: When visitors leave your website without taking any action.
# 2. Low click-through rates: When visitors fail to click on important links or buttons.
# 3. Abandoned shopping carts: When visitors add items to their cart but do not complete the purchase.
# 4. Lack of form submissions: When visitors do not fill out important forms on your website.
# 5. Slow page load times: When your website takes too long to load, causing visitors to leave.
#
# Prioritizing Conversion Problems
#
# To effectively address conversion problems, it is important to prioritize them based on their impact, frequency, alignment with business goals, and resources required for resolution. By prioritizing, you can focus your efforts on the most critical issues. Consider the following factors when prioritizing conversion problems:
#
# 1. Impact on overall conversion rate: Address problems that have the greatest impact on your conversion rates.
# 2. Frequency of occurrence: Focus on problems that occur frequently and affect a large number of visitors.
# 3. Alignment with business goals: Prioritize problems that align with your business objectives and target audience.
# 4. Resources required for resolution: Consider the time, effort, and resources needed to address each problem.
#
# Creating a Conversion Roadmap
#
# To create a conversion roadmap, follow these steps:
#
# 1. Conduct a website audit: Evaluate your website's performance, user experience, and conversion metrics.
# 2. Analyze data and metrics: Use tools like Google Analytics to gather data and identify areas for improvement.
# 3. Identify conversion problem areas: Based on your analysis, pinpoint the specific areas where conversion problems are occurring.
# 4. Prioritize conversion problems: Rank the identified problems based on their importance and impact.
# 5. Set specific goals and objectives: Define what you want to achieve with your conversion optimization efforts.
# 6. Develop strategies and tactics: Create a plan to address each conversion problem, outlining the steps and actions needed.
# 7. Implement and test solutions: Put your strategies into action and test their effectiveness.
# 8. Monitor and measure results: Continuously track and analyze the impact of your solutions on your conversion rates.
#
# Case Studies and Examples
#
# To further illustrate the effectiveness of conversion roadmaps, we provide real-life examples of successful optimization efforts. These case studies highlight the strategies and tactics used to overcome conversion problems and achieve significant improvements in conversion rates. By learning from these examples, you can gain valuable insights for your own conversion optimization journey.
#
# Conclusion
#
# In conclusion, creating a conversion roadmap is a crucial step in boosting your conversion rates and optimizing your online store's performance. By understanding and addressing conversion problems, prioritizing your efforts, and implementing effective strategies, you can achieve significant improvements in your conversion rates. Remember to continuously monitor and measure your results to ensure ongoing success. For more information and resources on conversion optimization, check out the links below:
#
# - [A Beginner's Guide to A/B Testing](https://www.abconvert.io/blog/beginners-guide-to-a-b-testing)
# - [Enhancing E-commerce Success: A Comprehensive Guide to A/B Testing for Conversion Rate Optimization](https://www.abconvert.io/blog/enhancing-e-commerce-success-a-comprehensive-guide-to-a-b-testing-for-conversion-rate-optimization)
# - [The Ultimate Guide to Optimizing Your Shopify Store with ABConvert](https://www.abconvert.io/blog/the-ultimate-guide-to-optimizing-your-shopify-store-with-abconvert)
#
# Remember, improving your conversion rates is a continuous process, and with the right roadmap, you can achieve great success.
#
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-XsbS2SJ0y6rGde6yJBagVpWT/user-A4WpGwDF6YUHHn0rJoaDsjhh/img-mmpelVygy3XhsKxFQYNV8zPM.png?st=2024-01-25T00%3A13%3A22Z&se=2024-01-25T02%3A13%3A22Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-01-24T22%3A08%3A10Z&ske=2024-01-25T22%3A08%3A10Z&sks=b&skv=2021-08-06&sig=yZb6ixREscWVaHYDucd3N8TEJAxtTDugjmF4q1KAr1s%3D
#
# {
#   "title": "Creating a Conversion Roadmap: A Step-by-Step Guide to Boosting Your Conversion Rates",
#   "blog picture link": "https://oaidalleapiprodscus.blob.core.windows.net/private/org-XsbS2SJ0y6rGde6yJBagVpWT/user-A4WpGwDF6YUHHn0rJoaDsjhh/img-mmpelVygy3XhsKxFQYNV8zPM.png?st=2024-01-25T00%3A13%3A22Z&se=2024-01-25T02%3A13%3A22Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-01-24T22%3A08%3A10Z&ske=2024-01-25T22%3A08%3A10Z&sks=b&skv=2021-08-06&sig=yZb6ixREscWVaHYDucd3N8TEJAxtTDugjmF4q1KAr1s%3D",
#   "primary keyword": "Conversion Roadmap",
#   "other_keywords": [
#     "Conversion optimization",
#     "Boosting conversion rates",
#     "Conversion problems",
#     "Bounce rates",
#     "Click-through rates",
#     "Abandoned shopping carts",
#     "Form submissions",
#     "Page load times",
#     "Prioritization",
#     "Website audit"
#   ],
#   "funnel": "top",
#   "minutes": 2.09,
#   "date": "2024-01-24",
#   "reference": "https://www.invespcro.com/blog/creating-a-conversion-roadmap-how-to-prioritize-conversion-problems-on-your-website/"
# }

# %%
# Set a timeout in seconds (adjust as needed) as Time limit for checking each rule.
timeout_seconds = 60  # 1 minutes

# %%
checking_places = [
    #rule 3
    "All article content must be generated based on the instructions provided in the following format: ```{instructions}```. \
        Ensure that the article strictly adheres to these guidelines.",
    #rule 2
    "Each heading in the article must exactly match a corresponding point in the outline, which is formatted as a bulleted list. \
        Headings should not include any prefixes such as 'H2' or 'Section'. For instance, if the outline lists 'Introduction to Biology', the article must use 'Introduction to Biology' as the heading, not 'Section 1: Introduction to Biology'. If an article heading does not match the outline, provide an example of a non-compliant heading.",
    #rule 4
    "The article must include at least one ordered (numbered) or unordered (bulleted) list. These lists should be formatted in Markdown (e.g., '* Item' for unordered lists, '1. Item' for ordered lists) and must appear under a heading formatted as either '##' (H2) or '###' (H3).",
    #rule 5
    "The article should be written in a manner that is easily understandable by individuals at a 6th-grade reading level. This involves using simple language, short sentences, and clear explanations of any complex terms or concepts.",
    #rule 6
    "Each heading (formatted as '##' for H2 and '###' for H3) must be followed by at least five sentences of relevant content. Additionally, for every ordered or unordered list in the article, there must be accompanying explanations and examples followed by at least three sentences for each list item, formatted in Markdown.",
    #rule 7 
    "Total words in the articles is between 1500 to 2000 words.",
    #rule 1
    "The entire article must be formatted using Markdown syntax. \
        This includes using Markdown for headings, paragraphs, lists, bold and italic text, and hyperlinks. \
        Ensure that the formatting is consistent and follows standard Markdown conventions."
]

# %%
# prompt for fix the rules
prompt_revise_problem = [
    #rule 3
    "Modify the content to ensure it aligns with and accurately reflects the guidelines provided in the ```{instructions}```. \
        If any part of the article deviates from these instructions, revise it accordingly to meet the specified requirements. ",
    #rule 2
    "Remove any prefixes like 'H2' or 'Section' from the headings. For instance, change 'Section 1: Introduction to Biology' to 'Introduction to Biology' as per the outline.",
    #rule 4
    "Include at least one ordered (numbered) or unordered (bulleted) list in the article. Place this list under a heading formatted as either '##' for H2 headings or '###' for H3 headings. Use the Markdown format for lists, e.g., '* Bullet point' for unordered lists and '1. Item' for ordered lists.",
    #rule 5
    "Revise the article for a 6th-grade reading level. Simplify complex sentences, use more common words, and break down complicated concepts into easier-to-understand elements.",
    #rule 6
    "Ensure that each heading (formatted as '##' for H2 and '###' for H3) is followed by at least five sentences of explanatory text. No upper limit. Additionally, for each ordered or unordered list, provide explanations and examples for the listed items by at least two sentences of explanatory text. No upper limit. The lists should be in Markdown format.",
    #rule 7
    "Rewrite the article for a total word count between 1500 to 2000 words",
    #rule 1 
    f"""Convert the given article into Markdown format using all parts of <sample markdown>. 
        <sample markdown>

        This is some basic, sample markdown.
        # H1 for article
        ## H2. Second Heading


        * Unordered lists, and:
        1. One
        2. Two
        3. Three
        * More

        > Blockquote

        And **bold**, *italics*, and even *italics and later **bold***. Even ~~strikethrough~~. [A link](https://markdowntohtml.com) to somewhere.

        </sample markdown>"""
]

# %%
def generate_check_prompt(rule, new_outline, testing_text):
    return f"""
    Check the article against ```{rule}```. Tell Yes or No. \
    Please provide a detailed response in one-line output indicating which an example in the article. \
    If you cannot find the example of the places in the article, please re-check the rule.

    outline: ```{new_outline}```
    article: ```{testing_text}```
    """

def generate_regenerate_prompt(i, new_outline, testing_text):
    return f"""
    ```{prompt_revise_problem[i]}```. Revise the least places in the article and return the all article after revision at the end. 

    outline: ```{new_outline}```
    article: ```{testing_text}```
    """

# %%
# Iterates through a list of rules for checking places in the article. 
# The code prompts the user to check if the article adheres to each rule, providing a detailed response. 
# If the response indicates a rule violation, the code prompts for article revision and repeats the checking process.
# Return the final revised version of the article after checking against all rules.

testing_text = artilce
rule_number = 0 # showcase the number of rule
new_outline = get_new_outline()



for rule in checking_places:
    check_prompt = generate_check_prompt(rule, new_outline, testing_text)

    start_time = time.time() # Record the start time

    while get_completion(check_prompt).startswith("No"):
        # Check the elapsed time
        elapsed_time = time.time() - start_time
        if elapsed_time > timeout_seconds:
            print(f"Time limit exceeded for rule: {rule}")
            break  # Break out of the loop if time limit exceeded

        regenerate_prompt = generate_regenerate_prompt(rule_number, new_outline, testing_text)
        testing_text = get_completion(regenerate_prompt)
        
        check_prompt = generate_check_prompt(rule, new_outline, testing_text)

    
    rule_number += 1

final_article = testing_text
print(final_article)
# Out:
# Time limit exceeded for rule: All article content must be generated based on the instructions provided in the following format: ```{instructions}```.         Ensure that the article strictly adheres to these guidelines.
# Time limit exceeded for rule: The article should be written in a manner that is easily understandable by individuals at a 6th-grade reading level. This involves using simple language, short sentences, and clear explanations of any complex terms or concepts.
# Time limit exceeded for rule: Each heading (formatted as '##' for H2 and '###' for H3) must be followed by at least five sentences of relevant content. Additionally, for every ordered or unordered list in the article, there must be accompanying explanations and examples followed by at least three sentences for each list item, formatted in Markdown.
# Time limit exceeded for rule: Total words in the articles is between 1500 to 2000 words.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9140/4075502767.py in <module>
#      23
#      24         regenerate_prompt = generate_regenerate_prompt(rule_number, new_outline, testing_text)
# ---> 25         testing_text = get_completion(regenerate_prompt)
#      26
#      27         check_prompt = generate_check_prompt(rule, new_outline, testing_text)
#
# c:\Users\jenny\AppData\Local\vscode-sqltools\Data\session\lanchain\contentGeneration.py in get_completion(prompt, model)
#      25 def get_completion(prompt, model="gpt-3.5-turbo"):
#      26     messages = [{"role": "user", "content": prompt}]
# ---> 27     response = client.chat.completions.create(
#      28         model=model,
#      29         messages=messages,
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\openai\_utils\_utils.py in wrapper(*args, **kwargs)
#     269                         msg = f"Missing required argument: {quote(missing[0])}"
#     270                 raise TypeError(msg)
# --> 271             return func(*args, **kwargs)
#     272
#     273         return wrapper  # type: ignore
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\openai\resources\chat\completions.py in create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     641         timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     642     ) -> ChatCompletion | Stream[ChatCompletionChunk]:
# --> 643         return self._post(
#     644             "/chat/completions",
#     645             body=maybe_transform(
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\openai\_base_client.py in post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1110             method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1111         )
# -> 1112         return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#    1113
#    1114     def patch(
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\openai\_base_client.py in request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     857         stream_cls: type[_StreamT] | None = None,
#     858     ) -> ResponseT | _StreamT:
# --> 859         return self._request(
#     860             cast_to=cast_to,
#     861             options=options,
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\openai\_base_client.py in _request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     885
#     886         try:
# --> 887             response = self._client.send(
#     888                 request,
#     889                 stream=stream or self._should_stream_response_body(request=request),
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\httpx\_client.py in send(self, request, stream, auth, follow_redirects)
#     913         auth = self._build_request_auth(request, auth)
#     914
# --> 915         response = self._send_handling_auth(
#     916             request,
#     917             auth=auth,
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\httpx\_client.py in _send_handling_auth(self, request, auth, follow_redirects, history)
#     941
#     942             while True:
# --> 943                 response = self._send_handling_redirects(
#     944                     request,
#     945                     follow_redirects=follow_redirects,
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\httpx\_client.py in _send_handling_redirects(self, request, follow_redirects, history)
#     978                 hook(request)
#     979
# --> 980             response = self._send_single_request(request)
#     981             try:
#     982                 for hook in self._event_hooks["response"]:
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\httpx\_client.py in _send_single_request(self, request)
#    1014
#    1015         with request_context(request=request):
# -> 1016             response = transport.handle_request(request)
#    1017
#    1018         assert isinstance(response.stream, SyncByteStream)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\httpx\_transports\default.py in handle_request(self, request)
#     229         )
#     230         with map_httpcore_exceptions():
# --> 231             resp = self._pool.handle_request(req)
#     232
#     233         assert isinstance(resp.stream, typing.Iterable)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\httpcore\_sync\connection_pool.py in handle_request(self, request)
#     266                 with ShieldCancellation():
#     267                     self.response_closed(status)
# --> 268                 raise exc
#     269             else:
#     270                 break
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\httpcore\_sync\connection_pool.py in handle_request(self, request)
#     249
#     250             try:
# --> 251                 response = connection.handle_request(request)
#     252             except ConnectionNotAvailable:
#     253                 # The ConnectionNotAvailable exception is a special case, that
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\httpcore\_sync\connection.py in handle_request(self, request)
#     101                 raise ConnectionNotAvailable()
#     102
# --> 103         return self._connection.handle_request(request)
#     104
#     105     def _connect(self, request: Request) -> NetworkStream:
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\httpcore\_sync\http11.py in handle_request(self, request)
#     131                 with Trace("response_closed", logger, request) as trace:
#     132                     self._response_closed()
# --> 133             raise exc
#     134
#     135     # Sending the request...
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\httpcore\_sync\http11.py in handle_request(self, request)
#     109                     reason_phrase,
#     110                     headers,
# --> 111                 ) = self._receive_response_headers(**kwargs)
#     112                 trace.return_value = (
#     113                     http_version,
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\httpcore\_sync\http11.py in _receive_response_headers(self, request)
#     174
#     175         while True:
# --> 176             event = self._receive_event(timeout=timeout)
#     177             if isinstance(event, h11.Response):
#     178                 break
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\httpcore\_sync\http11.py in _receive_event(self, timeout)
#     210
#     211             if event is h11.NEED_DATA:
# --> 212                 data = self._network_stream.read(
#     213                     self.READ_NUM_BYTES, timeout=timeout
#     214                 )
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\httpcore\_backends\sync.py in read(self, max_bytes, timeout)
#     124         with map_exceptions(exc_map):
#     125             self._sock.settimeout(timeout)
# --> 126             return self._sock.recv(max_bytes)
#     127
#     128     def write(self, buffer: bytes, timeout: typing.Optional[float] = None) -> None:
#
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.9_3.9.3568.0_x64__qbz5n2kfra8p0\lib\ssl.py in recv(self, buflen, flags)
#    1225                     "non-zero flags not allowed in calls to recv() on %s" %
#    1226                     self.__class__)
# -> 1227             return self.read(buflen)
#    1228         else:
#    1229             return super().recv(buflen, flags)
#
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.9_3.9.3568.0_x64__qbz5n2kfra8p0\lib\ssl.py in read(self, len, buffer)
#    1100                 return self._sslobj.read(len, buffer)
#    1101             else:
# -> 1102                 return self._sslobj.read(len)
#    1103         except SSLError as x:
#    1104             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:
