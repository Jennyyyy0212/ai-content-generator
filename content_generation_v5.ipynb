# %%
# !pip  install openai

# %%
# import packages and openai_key
import openai
import os
import time
import datetime
from openai import OpenAI

from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())

os.environ['OPENAI_API_KEY'] = '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'

openai.api_key  = os.getenv('OPENAI_API_KEY')

# %%
# need to be change each time
keyword = "basic cro"

# %%
# set up the function 
client = OpenAI(api_key=os.environ.get("OPENAI_API_KEY"),)

def get_completion(prompt, model="gpt-3.5-turbo"):
    messages = [{"role": "user", "content": prompt}]
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=0
    )
    return response.choices[0].message.content

# %%
# set a time of the start time of generating a content
total_start_time = time.time()

# Set a timeout in seconds (adjust as needed) as Time limit for checking each rule.
timeout_seconds = 60  # 1 minutes

#get today's date for record
today_date = datetime.date.today()

# %%
#create avatar list in funnels
top_funnel = f""" 
The target audience consists of individuals with basic to intermediate knowledge of A/B testing and e-commerce. \
They aim to optimize their e-commerce efforts and are interested in using A/B testing tools or advancing their techniques. \
They are typically professionals in relevant fields, active online users, and motivated to improve business performance through A/B testing. \
Communication should focus on practical insights through online channels and technical language is acceptable.
"""

middle_funnel = f""" 
e-commerce merchant and those who want to improve CRO(conversion rate optimization)

Demographics: Your audience primarily consists of e-commerce merchants. These individuals are likely business owners or key decision-makers in small to medium-sized online retail businesses. Their age range could vary widely, but they are typically adults who are tech-savvy and comfortable with digital platforms.

Professional Background: They have a background in online sales, digital marketing, or e-commerce management. Their experience level in the e-commerce sector might range from beginners to seasoned professionals. They are constantly seeking ways to improve their online business performance.

Challenges and Pain Points: These individuals often grapple with challenges like low website traffic, poor conversion rates, abandoned shopping carts, and intense competition in the online marketplace. They are seeking effective strategies to optimize their websites to enhance customer experience and increase sales.

Goals and Aspirations: Their primary goal is to increase the conversion rate of their e-commerce site. This includes improving website design, enhancing user experience, streamlining the checkout process, and implementing effective marketing strategies. They aim to grow their business by attracting more customers and increasing sales.

Behavioral Traits: This audience is analytical and data-driven. They rely on metrics and analytics to make informed decisions. They are open to experimenting with new strategies and tools to enhance their website’s performance. They are active online, often seeking knowledge through blogs, webinars, online courses, and forums related to e-commerce and digital marketing.

Influences and Information Sources: They are influenced by successful e-commerce experts, digital marketing trends, and case studies of successful online businesses. They frequently visit e-commerce platforms, digital marketing blogs, social media channels, and online communities to stay updated with the latest trends and tools in the industry.

Values and Beliefs: They value customer satisfaction, business growth, and technological innovation. They believe in the power of digital transformation and the importance of staying ahead in the competitive online marketplace. They are committed to learning and adapting to improve their business.
"""

bottom_funnel = f""" 
Demographics:

Age: 28-45
Gender: Primarily female (60%) and male (40%)
Location: Urban and suburban areas in the US, Canada, UK
Income: Middle to high income
Education: Bachelor's degree or higher
Interests: E-commerce trends, marketing strategies, product quality, entrepreneurial communities.

Pain Points: Competition, rising marketing costs, customer retention, website optimization.

Goals: Increase sales, improve ROI, enhance customer engagement, expand product offerings.
"""


funnel_list = {'top':top_funnel, 'middle': middle_funnel, 'bottom': bottom_funnel}

# %%
checking_places = [
    #rule 1
    "The entire article must be formatted using Markdown syntax. \
        This includes using Markdown for headings, paragraphs, lists, bold and italic text, and hyperlinks. \
        Ensure that the formatting is consistent and follows standard Markdown conventions.", 
    #rule 2
    "Each heading in the article must exactly match a corresponding point in the outline, which is formatted as a bulleted list. \
        Headings should not include any prefixes such as 'H2' or 'Section'. For instance, if the outline lists 'Introduction to Biology', the article must use 'Introduction to Biology' as the heading, not 'Section 1: Introduction to Biology'. If an article heading does not match the outline, provide an example of a non-compliant heading.",
    #rule 3
    "All article content must be generated based on the instructions provided in the following format: ```{instructions}```. \
        Ensure that the article strictly adheres to these guidelines.",
    #rule 4
    "The article must include at least one ordered (numbered) or unordered (bulleted) list. These lists should be formatted in Markdown (e.g., '* Item' for unordered lists, '1. Item' for ordered lists) and must appear under a heading formatted as either '##' (H2) or '###' (H3).",
    #rule 5
    "The article should be written in a manner that is easily understandable by individuals at a 6th-grade reading level. This involves using simple language, short sentences, and clear explanations of any complex terms or concepts.",
    #rule 6
    "Each heading (formatted as '##' for H2 and '###' for H3) must be followed by at least five sentences of relevant content. Additionally, for every ordered or unordered list in the article, there must be accompanying explanations and examples followed by at least three sentences for each list item, formatted in Markdown.",
    #rule
    "Total words in the articles is between 1500 to 2000 words."
]

# %%
# prompt for fix the rules
prompt_revise_problem = [
    #rule 1
    f"""Convert the entire document into Markdown format using all parts of <sample markdown>. 
        <sample markdown>

        This is some basic, sample markdown.
        # H1 for article
        ## H2. Second Heading


        * Unordered lists, and:
        1. One
        2. Two
        3. Three
        * More

        > Blockquote

        And **bold**, *italics*, and even *italics and later **bold***. Even ~~strikethrough~~. [A link](https://markdowntohtml.com) to somewhere.

        </sample markdown>""", 
    #rule 2
    "Remove any prefixes like 'H2' or 'Section' from the headings. For instance, change 'Section 1: Introduction to Biology' to 'Introduction to Biology' as per the outline.",
    #rule 3
    "Modify the content to ensure it aligns with and accurately reflects the guidelines provided in the ```{instructions}```. \
        If any part of the article deviates from these instructions, revise it accordingly to meet the specified requirements. ",
    #rule 4
    "Include at least one ordered (numbered) or unordered (bulleted) list in the article. Place this list under a heading formatted as either '##' for H2 headings or '###' for H3 headings. Use the Markdown format for lists, e.g., '* Bullet point' for unordered lists and '1. Item' for ordered lists.",
    #rule 5
    "Revise the article for a 6th-grade reading level. Simplify complex sentences, use more common words, and break down complicated concepts into easier-to-understand elements.",
    #rule 6
    "Ensure that each heading (formatted as '##' for H2 and '###' for H3) is followed by at least five sentences of explanatory text. No upper limit. Additionally, for each ordered or unordered list, provide explanations and examples for the listed items by at least two sentences of explanatory text. No upper limit. The lists should be in Markdown format.",
    #rule 7
    "Rewrite the article for a total word count between 1500 to 2000 words"
]

# %%
import random
level = random.choice(["top","middle","bottom"])
selected_funnel = funnel_list.get(level)
## pick a ramdom funnel

# %%
# read the outline from the website link

website = f"""
https://capturly.com/guides/the-basics-of-conversion-rate-optimization/
"""
prompt = f"""
create an outline based on the article link
```{website}```
"""
outline = get_completion(prompt)
print(outline)
# Out:
# I. Introduction to Conversion Rate Optimization (CRO)
#    A. Definition of CRO
#    B. Importance of CRO for businesses
#
# II. Understanding Conversion Rates
#    A. Definition of conversion rate
#    B. Calculation of conversion rate
#    C. Factors influencing conversion rates
#
# III. Key Elements of Conversion Rate Optimization
#    A. User experience (UX) design
#       1. Importance of UX in CRO
#       2. Best practices for UX design
#    B. A/B testing
#       1. Definition of A/B testing
#       2. Benefits of A/B testing in CRO
#       3. Steps to conduct A/B testing
#    C. Website analytics
#       1. Importance of website analytics in CRO
#       2. Key metrics to track in website analytics
#    D. Conversion funnel optimization
#       1. Definition of conversion funnel
#       2. Strategies to optimize conversion funnel
#
# IV. Implementing Conversion Rate Optimization
#    A. Setting goals and objectives
#    B. Conducting research and analysis
#    C. Developing and implementing CRO strategies
#    D. Monitoring and measuring results
#
# V. Common Challenges in Conversion Rate Optimization
#    A. Lack of understanding of target audience
#    B. Insufficient data for analysis
#    C. Ineffective UX design
#    D. Inadequate testing and optimization
#
# VI. Conclusion
#    A. Recap of key points in CRO
#    B. Importance of continuous optimization for businesses.

# %%
# generate a clickable article title based on the provided outline and keyword.

prompt = f"""
Based on the outline, create a clickable article title that included the keyword and revise the outline to be used in my owm article based on revised title \
It shouldn't include any other brand service or product. 
keyword: ```{keyword}```
outline: ```{outline}```
"""
new_outline = get_completion(prompt)
print(new_outline)
# Out:
# Title: "The Basics of Conversion Rate Optimization (CRO): A Comprehensive Guide"
#
# Revised Outline:
#
# I. Introduction to Conversion Rate Optimization (CRO)
#    A. Definition of CRO
#    B. Importance of CRO for businesses
#
# II. Understanding Conversion Rates
#    A. Definition of conversion rate
#    B. Calculation of conversion rate
#    C. Factors influencing conversion rates
#
# III. Key Elements of Conversion Rate Optimization
#    A. User experience (UX) design
#       1. Importance of UX in CRO
#       2. Best practices for UX design
#    B. A/B testing
#       1. Definition of A/B testing
#       2. Benefits of A/B testing in CRO
#       3. Steps to conduct A/B testing
#    C. Website analytics
#       1. Importance of website analytics in CRO
#       2. Key metrics to track in website analytics
#    D. Conversion funnel optimization
#       1. Definition of conversion funnel
#       2. Strategies to optimize conversion funnel
#
# IV. Implementing Conversion Rate Optimization
#    A. Setting goals and objectives
#    B. Conducting research and analysis
#    C. Developing and implementing CRO strategies
#    D. Monitoring and measuring results
#
# V. Common Challenges in Conversion Rate Optimization
#    A. Lack of understanding of target audience
#    B. Insufficient data for analysis
#    C. Ineffective UX design
#    D. Inadequate testing and optimization
#
# VI. Conclusion
#    A. Recap of key points in CRO
#    B. Importance of continuous optimization for businesses.

# %%
# list the 10 related keywords

prompt = f"""
Based on the new outline, list some keywords that related the content and title in total of 10. Do not include the primpary keyword.
primary keyword: ```{keyword}```
outline: ```{new_outline}```
"""
other_keywords = get_completion(prompt)
print(other_keywords)
# Out:
# 1. Conversion Rate Optimization
# 2. Definition
# 3. Importance
# 4. Conversion Rates
# 5. Calculation
# 6. Factors
# 7. User Experience Design
# 8. A/B Testing
# 9. Website Analytics
# 10. Conversion Funnel Optimization

# %%
instructions = f"""
Rewrite this title. Write the article readable for people in 6th grade. Use the headings and subheadings but use different words. \
Do not use the brands from the outline, use my brands from the XML <internal links>. \
Once you've used an internal link, do not use that internal link again. \
Take the <avatar> and write an article specifically for that person. Your tone should match the needs of the <avatar>. Do not mention the <avatar>. \
Do not mention other companies or brands, but focus more on educational or informative content. \
Write with a huge degree of creativity and informative burstiness. Try to include <keywords> as much as possible. \
Naturally add the primary keywords and other keywords into articles.  Explain nouns or ideas with examples and detailed explanations. \
Do not  mention any brand, services, or products. It is informative content. Create pictures to explain the ideas. \
Include all of the following HTML formatting at least once:

<sample markdown>

This is some basic, sample markdown.
# H1 for article
## H2. Second Heading


 * Unordered lists, and:
  1. One
  2. Two
  3. Three
 * More

> Blockquote

And **bold**, *italics*, and even *italics and later **bold***. Even ~~strikethrough~~. [A link](https://markdowntohtml.com) to somewhere.

</sample markdown>

Use all parts of <sample markdown>. Use the <outline> with the Focus keyword . Articles should include the h1, h2, h3 font size. where H1 is used for main title of the article and include the Focus keyword in <outline>. H2 are headings that break up the main sections of your content, add most keywords here, plan on around 3-5 of these H2s in 1000 words article. H3 are break up and list individual points in the main sections, in the form of numbered lists or clarifying sections to an H2 heading, for <keywords>

Firstly, write an introduction, with one paragraph, and an unordered list summarizing the entire article

Secondly, write the first half of the main part of the content, write at least 5 paragraphs.

Thirdly, write the second half of the main part of the content, write at least 3 paragraphs

Finally, write the conclusion, and include some links to other similar blogs at the bottom, write one paragraph.


<outline>

Focus keyword: ```{keyword}```

title and outline: ```{new_outline}```

</outline>

<avatar>

funnel: ```{selected_funnel}```

</avatar>

<keywords>

```{other_keywords}```

</keywords>

<internal links>

http://help.abconvert.io/en/
https://abconvert.io/
https://help.abconvert.io/
https://help.abconvert.io/cdn-cgi/l/email-protection
https://help.abconvert.io/en/
https://help.abconvert.io/en/articles/7991764-how-does-abconvert-work
https://help.abconvert.io/en/articles/7992482-how-to-run-price-test-only-on-new-customer
https://help.abconvert.io/en/articles/7994393-how-abconvert-analytics-works
https://help.abconvert.io/en/articles/8517478-how-to-start-a-url-redirect-test
https://help.abconvert.io/en/articles/8522853-how-to-test-product-price-shipping-at-the-same-time
https://help.abconvert.io/en/articles/8540376-how-to-find-product-using-advanced-search
https://help.abconvert.io/en/articles/8663230-how-to-set-up-utm-filter-for-price-test
https://help.abconvert.io/en/articles/8663287-how-to-end-test-safely-on-recharge-subscription-products
https://help.abconvert.io/en/articles/8676035-how-to-start-a-price-test
https://help.abconvert.io/en/articles/8726911-how-to-manage-duplicate-product
https://help.abconvert.io/en/articles/8730805-how-to-run-a-price-test-only-in-the-selected-countries
https://help.abconvert.io/en/articles/8735286-how-to-sync-inventory-for-your-test-products
https://help.abconvert.io/en/collections/3907966-shipping-rate-test
https://help.abconvert.io/en/collections/4080621-onboarding
https://help.abconvert.io/en/collections/4080626-advanced-topic
https://www.abconvert.io/
https://www.abconvert.io/abconvert-vs-intelligems
https://www.abconvert.io/blog
https://www.abconvert.io/blog/beginners-guide-to-a-b-testing
https://www.abconvert.io/blog/enhancing-e-commerce-success-a-comprehensive-guide-to-a-b-testing-for-conversion-rate-optimization
https://www.abconvert.io/blog/glossary-a-b-testing-essentials-for-e-commerce
https://www.abconvert.io/blog/mastering-price-testing-in-e-commerce-with-the-ice-framework
https://www.abconvert.io/blog/price-test-basics-how-to-optimize-your-e-commerce-store
https://www.abconvert.io/blog/the-art-of-price-testing-key-to-maximizing-store-profits
https://www.abconvert.io/blog/the-psychology-of-online-shopping-understanding-consumer-behavior
https://www.abconvert.io/blog/the-ultimate-guide-to-optimizing-your-shopify-store-with-abconvert
https://www.abconvert.io/blog/understanding-split-testing-a-comparative-look-with-a-b-testing
https://www.abconvert.io/blog/why-black-friday-is-the-best-day-for-price-testing
https://www.abconvert.io/contact-us
https://www.abconvert.io/features
https://www.abconvert.io/pricing
https://www.abconvert.io/privacy-policy
https://www.abconvert.io/why-a-b-test

</internal links>

"""

# %%
# creating the article with instructions

prompt = f"""
create the whole article follow by instructions. 
```{instructions}```
"""
article = get_completion(prompt)
print(article)
# Out:
# The Basics of Conversion Rate Optimization (CRO): A Comprehensive Guide
#
# Introduction to Conversion Rate Optimization (CRO)
# Conversion Rate Optimization (CRO) is an essential strategy for businesses to improve their online performance. By optimizing the conversion rate, businesses can increase sales, improve ROI, and enhance customer engagement. In this comprehensive guide, we will explore the key elements of CRO, how to implement it effectively, and the common challenges faced in the process.
#
# Understanding Conversion Rates
# Conversion rate refers to the percentage of website visitors who complete a desired action, such as making a purchase or filling out a form. It is calculated by dividing the number of conversions by the total number of visitors. Several factors influence conversion rates, including website design, user experience, and the effectiveness of the conversion funnel.
#
# Key Elements of Conversion Rate Optimization
# 1. User Experience (UX) Design
#    User experience plays a crucial role in CRO. A well-designed website that is easy to navigate and visually appealing can significantly impact conversion rates. Best practices for UX design include clear call-to-action buttons, intuitive navigation menus, and responsive design for mobile devices.
#
# 2. A/B Testing
#    A/B testing is a method used to compare two versions of a webpage or element to determine which one performs better in terms of conversions. By testing different variations, businesses can identify the most effective design, layout, or content that drives higher conversion rates. Steps to conduct A/B testing include creating hypotheses, designing variations, running the test, and analyzing the results.
#
# 3. Website Analytics
#    Website analytics provide valuable insights into user behavior and help businesses understand how visitors interact with their website. By tracking key metrics such as bounce rate, time on page, and conversion funnel progression, businesses can identify areas for improvement and make data-driven decisions to optimize conversion rates.
#
# 4. Conversion Funnel Optimization
#    The conversion funnel represents the journey a visitor takes from landing on a website to completing a desired action. Optimizing the conversion funnel involves identifying potential drop-off points and implementing strategies to reduce friction and improve the user experience. This can include simplifying the checkout process, offering incentives, or providing clear and persuasive messaging.
#
# Implementing Conversion Rate Optimization
# To implement CRO effectively, businesses should follow these steps:
#
# 1. Setting Goals and Objectives
#    Clearly define the desired outcomes and objectives of the CRO efforts. This could include increasing sales, improving lead generation, or enhancing user engagement.
#
# 2. Conducting Research and Analysis
#    Gather data on user behavior, website performance, and industry benchmarks. This research will provide insights into areas that need improvement and help prioritize optimization efforts.
#
# 3. Developing and Implementing CRO Strategies
#    Based on the research and analysis, develop strategies to optimize conversion rates. This could involve making design changes, testing different variations, or improving the user experience.
#
# 4. Monitoring and Measuring Results
#    Continuously monitor the performance of the implemented strategies and measure the impact on conversion rates. Make adjustments as needed and iterate on the optimization process.
#
# Common Challenges in Conversion Rate Optimization
# 1. Lack of Understanding of Target Audience
#    Without a clear understanding of the target audience, it can be challenging to create effective strategies that resonate with potential customers. Conducting market research and gathering customer feedback can help overcome this challenge.
#
# 2. Insufficient Data for Analysis
#    Accurate and comprehensive data is crucial for effective CRO. Businesses should ensure they have the necessary tools and systems in place to collect and analyze relevant data.
#
# 3. Ineffective UX Design
#    Poorly designed websites can lead to high bounce rates and low conversion rates. Investing in UX design and following best practices can help overcome this challenge.
#
# 4. Inadequate Testing and Optimization
#    Testing and optimization are ongoing processes in CRO. Businesses should allocate sufficient time and resources to continuously test and optimize their websites to achieve optimal conversion rates.
#
# Conclusion
# Conversion Rate Optimization (CRO) is a vital strategy for businesses looking to improve their online performance. By understanding conversion rates, implementing key elements of CRO, and overcoming common challenges, businesses can enhance their conversion rates, increase sales, and achieve their goals. Continuous optimization is essential for long-term success in the ever-evolving digital landscape.
#
# For more information on CRO and related topics, check out these helpful resources:
# - [A Beginner's Guide to A/B Testing](https://www.abconvert.io/blog/beginners-guide-to-a-b-testing)
# - [Enhancing E-commerce Success: A Comprehensive Guide to A/B Testing for Conversion Rate Optimization](https://www.abconvert.io/blog/enhancing-e-commerce-success-a-comprehensive-guide-to-a-b-testing-for-conversion-rate-optimization)
# - [The Ultimate Guide to Optimizing Your Shopify Store with ABConvert](https://www.abconvert.io/blog/the-ultimate-guide-to-optimizing-your-shopify-store-with-abconvert)

# %%
# Iterates through a list of rules for checking places in the article. 
# The code prompts the user to check if the article adheres to each rule, providing a detailed response. 
# If the response indicates a rule violation, the code prompts for article revision and repeats the checking process.
# Return the final revised version of the article after checking against all rules.

testing_text = article 
i = 0 # showcase the number of rule

for rule in checking_places:
    check_prompt = f"""
    Check the article against ```{rule} ```. Tell Yes or No. \
    Please provide a detailed response in one-line output indicating which an example in the article. \
    If you cannot find the example of the places in the article, please re-check the rule.

    outline: ```{new_outline}```
    article: ```{testing_text}```
    """

    start_time = time.time() # Record the start time

    while get_completion(check_prompt).startswith("No"):
        # Check the elapsed time
        elapsed_time = time.time() - start_time
        if elapsed_time > timeout_seconds:
            print(f"Time limit exceeded for rule: {rule}")
            break  # Break out of the loop if time limit exceeded

        regenerate_prompt = f"""
        ```{prompt_revise_problem[i]} ```. Revise the least places in the article and return the all article after revision at the end. 

        outline: ```{new_outline}```
        article: ```{testing_text}```
        """
        testing_text = get_completion(regenerate_prompt)
        
        check_prompt = f"""
        Check the article against ```{rule} ```. Tell Yes or No. \
        Please provide a detailed response in one-line output indicating which an example in the article. \
        If you cannot find the example of the places in the article, please re-check the rule.

        outline: ```{new_outline}```
        article: ```{testing_text}```
        """
    i = i+ 1
print(testing_text)
total_finish_time = time.time()
duration = round((total_finish_time - total_start_time) / 60,2)
# Out:
# Time limit exceeded for rule: The article should be written in a manner that is easily understandable by individuals at a 6th-grade reading level. This involves using simple language, short sentences, and clear explanations of any complex terms or concepts.
# Title: "The Basics of Conversion Rate Optimization (CRO): A Comprehensive Guide"
#
# Revised Outline:
#
# I. Introduction to Conversion Rate Optimization (CRO)
#    A. Definition of CRO
#    B. Importance of CRO for businesses
#
# II. Understanding Conversion Rates
#    A. Definition of conversion rate
#    B. How to calculate conversion rate
#    C. Factors that affect conversion rates
#
# III. Key Elements of Conversion Rate Optimization
#    A. User Experience (UX) Design
#       1. Why UX is important in CRO
#       2. Best practices for UX design
#    B. A/B Testing
#       1. What is A/B testing
#       2. Benefits of A/B testing in CRO
#       3. Steps to conduct A/B testing
#    C. Website Analytics
#       1. Why website analytics is important in CRO
#       2. Key metrics to track in website analytics
#    D. Conversion Funnel Optimization
#       1. What is a conversion funnel
#       2. Strategies to improve conversion funnel
#
# IV. Implementing Conversion Rate Optimization
#    A. Setting goals and objectives
#    B. Conducting research and analysis
#    C. Developing and implementing CRO strategies
#    D. Monitoring and measuring results
#
# V. Common Challenges in Conversion Rate Optimization
#    A. Lack of understanding of target audience
#    B. Not enough data for analysis
#    C. Poor UX design
#    D. Inadequate testing and optimization
#
# VI. Conclusion
#    A. Recap of key points in CRO
#    B. Importance of continuous optimization for businesses.
#
# Article:
#
# The Basics of Conversion Rate Optimization (CRO): A Comprehensive Guide
#
# Introduction to Conversion Rate Optimization (CRO)
# Conversion Rate Optimization (CRO) is an important strategy for businesses to improve their online performance. By optimizing the conversion rate, businesses can increase sales, improve return on investment (ROI), and enhance customer engagement. In this guide, we will explore the key elements of CRO, how to implement it effectively, and the common challenges faced in the process.
#
# Understanding Conversion Rates
# Conversion rate refers to the percentage of website visitors who complete a desired action, such as making a purchase or filling out a form. To calculate the conversion rate, divide the number of conversions by the total number of visitors. Several factors influence conversion rates, including website design, user experience, and the effectiveness of the conversion funnel.
#
# Key Elements of Conversion Rate Optimization
# 1. User Experience (UX) Design
#    User experience plays a crucial role in CRO. A well-designed website that is easy to navigate and visually appealing can significantly impact conversion rates. Best practices for UX design include clear buttons for actions, easy-to-use menus, and designs that work well on mobile devices.
#
# 2. A/B Testing
#    A/B testing is a method used to compare two versions of a webpage or element to determine which one performs better in terms of conversions. By testing different variations, businesses can identify the most effective design, layout, or content that drives higher conversion rates. Steps to conduct A/B testing include creating ideas, making different versions, running the test, and analyzing the results.
#
# 3. Website Analytics
#    Website analytics provide valuable insights into user behavior and help businesses understand how visitors interact with their website. By tracking key metrics such as bounce rate, time on page, and conversion funnel progression, businesses can identify areas for improvement and make data-driven decisions to optimize conversion rates.
#
# 4. Conversion Funnel Optimization
#    The conversion funnel represents the journey a visitor takes from landing on a website to completing a desired action. Optimizing the conversion funnel involves identifying potential drop-off points and implementing strategies to reduce friction and improve the user experience. This can include simplifying the checkout process, offering incentives, or providing clear and persuasive messages.
#
# Implementing Conversion Rate Optimization
# To implement CRO effectively, businesses should follow these steps:
#
# 1. Setting Goals and Objectives
#    Clearly define the desired outcomes and objectives of the CRO efforts. This could include increasing sales, improving lead generation, or enhancing user engagement.
#
# 2. Conducting Research and Analysis
#    Gather data on user behavior, website performance, and industry benchmarks. This research will provide insights into areas that need improvement and help prioritize optimization efforts.
#
# 3. Developing and Implementing CRO Strategies
#    Based on the research and analysis, develop strategies to optimize conversion rates. This could involve making design changes, testing different variations, or improving the user experience.
#
# 4. Monitoring and Measuring Results
#    Continuously monitor the performance of the implemented strategies and measure the impact on conversion rates. Make adjustments as needed and iterate on the optimization process.
#
# Common Challenges in Conversion Rate Optimization
# 1. Lack of Understanding of Target Audience
#    Without a clear understanding of the target audience, it can be challenging to create effective strategies that resonate with potential customers. Conducting market research and gathering customer feedback can help overcome this challenge.
#
# 2. Insufficient Data for Analysis
#    Accurate and comprehensive data is crucial for effective CRO. Businesses should ensure they have the necessary tools and systems in place to collect and analyze relevant data.
#
# 3. Ineffective UX Design
#    Poorly designed websites can lead to high bounce rates and low conversion rates. Investing in UX design and following best practices can help overcome this challenge.
#
# 4. Inadequate Testing and Optimization
#    Testing and optimization are ongoing processes in CRO. Businesses should allocate enough time and resources to continuously test and optimize their websites to achieve optimal conversion rates.
#
# Conclusion
# Conversion Rate Optimization (CRO) is a vital strategy for businesses looking to improve their online performance. By understanding conversion rates, implementing key elements of CRO, and overcoming common challenges, businesses can enhance their conversion rates, increase sales, and achieve their goals. Continuous optimization is essential for long-term success in the ever-evolving digital landscape.
#
# For more information on CRO and related topics, check out these helpful resources:
# - [A Beginner's Guide to A/B Testing](https://www.abconvert.io/blog/beginners-guide-to-a-b-testing)
# - [Enhancing E-commerce Success: A Comprehensive Guide to A/B Testing for Conversion Rate Optimization](https://www.abconvert.io/blog/enhancing-e-commerce-success-a-comprehensive-guide-to-a-b-testing-for-conversion-rate-optimization)
# - [The Ultimate Guide to Optimizing Your Shopify Store with ABConvert](https://www.abconvert.io/blog/the-ultimate-guide-to-optimizing-your-shopify-store-with-abconvert)

# %%
# create meta data in JSON

prompt = f"""
Create a JSON data structure designed to collect information on titles, keywords, and funnels. \
The structure should include keys named 'title', 'primary keyword', 'other_keywords', 'funnel', 'minutes' ,'date' , 'reference'. \
Each 'title' should be a string representing the title in the outline, \
    'primary keyword' should be the primary keyword, \
    'other keyword' should be the other keyword, \
    'funnel' should be the selected funnel, \
    and 'date' is the today's date in the format of MM-DD-YYYY. \


outline: ```{new_outline}```
primary keyword: ```{keyword}```
other keyword: ```{other_keywords}```
funnel: ```{level}```
minutes = ```{duration}```
date ```{today_date}```
reference: ```{website}```
"""

artilce_meta= get_completion(prompt)
print(artilce_meta)
# Out:
# {
#   "title": "The Basics of Conversion Rate Optimization (CRO): A Comprehensive Guide",
#   "primary keyword": "basic cro",
#   "other_keywords": [
#     "Conversion Rate Optimization",
#     "Definition",
#     "Importance",
#     "Conversion Rates",
#     "Calculation",
#     "Factors",
#     "User Experience Design",
#     "A/B Testing",
#     "Website Analytics",
#     "Conversion Funnel Optimization"
#   ],
#   "funnel": "middle",
#   "minutes": 16.23,
#   "date": "01-22-2024",
#   "reference": "https://capturly.com/guides/the-basics-of-conversion-rate-optimization/"
# }

# %%
back_up_checking_places = [
    #rule 1
    "The article is in markdowm format", 
    #rule 2
    "Each heading matches exactly with the corresponding point in the outline, without any unrelated prefixes like 'H2' or 'Section'. \
    The outline is formatted as a bulleted list, with each point being a potential section heading. \
    Please ensure that the text for each heading in the document is followed by the outline. \
    For example, if the outline has 'Introduction to Biology', the heading should also be 'Introduction to Biology' and not 'Section 1: Introduction to Biology'.\
    Check the above rule description carefully and provide one incorrect heading if the article against the rule.",
    #rule 3
    "All article content must be generated based on the instructions provided in the following format: ```{instructions}```. Ensure that the article strictly adheres to these guidelines.",
    #rule 4
    "include at least one ordered list or unorder list, representing in '* Unordered lists, and: 1. One 2. Two 3. Three * More' in markdown format, under a H2 heading or a H3 heading content",
    #rule 5
    "The article is readable for people in 6th grade.",
    #rule 6
    "Each heading, represetning in '## H2 heading ### H3 heading' has more than three sentences. Ordered or unorder lists, representing in '* Unordered lists, and: 1. One 2. Two 3. Three * More' in markdown format, mast have the explination has the explainations and exmaples "
]
