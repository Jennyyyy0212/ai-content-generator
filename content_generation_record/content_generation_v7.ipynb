# %%
# !pip  install openai

# %%
# import packages and openai_key
import openai
import os
import time
import datetime
from openai import OpenAI

from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())

os.environ['OPENAI_API_KEY'] = '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'

openai.api_key  = os.getenv('OPENAI_API_KEY')

# %%
# need to be change each time
keyword = "abandonment rate"

# %%
# set up the function 
client = OpenAI(api_key=os.environ.get("OPENAI_API_KEY"),)

# normal prompt generation 
def get_completion(prompt, model="gpt-3.5-turbo"):
    messages = [{"role": "user", "content": prompt}]
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=0
    )
    return response.choices[0].message.content

# %%
# set a time of the start time of generating a content
total_start_time = time.time()

# Set a timeout in seconds (adjust as needed) as Time limit for checking each rule.
timeout_seconds = 60  # 1 minutes

#get today's date for record
today_date = datetime.date.today()

# %%
#create avatar list in funnels
top_funnel = f""" 
Prospective Shopify owners and e-commerce enthusiasts who are relatively new to the online selling landscape. 
They may be exploring entrepreneurship opportunities, seeking to set up their first online store, or looking for ways to enhance their existing store. 
This group values simplicity and is eager to grasp the basics of e-commerce and A/B testing without diving too deep into technicalities. 
Their main goals include understanding the fundamentals of e-commerce, learning about Shopify, and gaining insights into the potential of A/B testing to optimize their store's performance. 
"""

middle_funnel = f""" 
E-commerce merchants in the growth phase who are actively looking to improve their Conversion Rate Optimization (CRO). 
This segment comprises business owners and marketing professionals with a moderate level of experience in running online stores. 
They are interested in detailed insights, case studies, and industry trends to implement effective CRO strategies. 
They appreciate practical guides, checklists, and analytics insights to optimize their conversion rates.
"""

bottom_funnel = f""" 
Experienced e-commerce professionals, marketers, and business owners who are well-versed in A/B testing but are now seeking advanced techniques and tools. 
This segment is specifically interested in service demos, sophisticated A/B testing frameworks, and understanding the psychology behind user behavior. 
They want to stay ahead of the curve with tools that offer in-depth analytics and insights. 
This group may also have a keen interest in ethical considerations and privacy aspects related to A/B testing.
"""


funnel_list = {'top':top_funnel, 'middle': middle_funnel, 'bottom': bottom_funnel}

# %%
checking_places = [
    #rule 3
    "All article content must be generated based on the instructions provided in the following format: ```{instructions}```. \
        Ensure that the article strictly adheres to these guidelines.",
    #rule 2
    "Each heading in the article must exactly match a corresponding point in the outline, which is formatted as a bulleted list. \
        Headings should not include any prefixes such as 'H2' or 'Section'. For instance, if the outline lists 'Introduction to Biology', the article must use 'Introduction to Biology' as the heading, not 'Section 1: Introduction to Biology'. If an article heading does not match the outline, provide an example of a non-compliant heading.",
    #rule 4
    "The article must include at least one ordered (numbered) or unordered (bulleted) list. These lists should be formatted in Markdown (e.g., '* Item' for unordered lists, '1. Item' for ordered lists) and must appear under a heading formatted as either '##' (H2) or '###' (H3).",
    #rule 5
    "The article should be written in a manner that is easily understandable by individuals at a 6th-grade reading level. This involves using simple language, short sentences, and clear explanations of any complex terms or concepts.",
    #rule 6
    "Each heading (formatted as '##' for H2 and '###' for H3) must be followed by at least five sentences of relevant content. Additionally, for every ordered or unordered list in the article, there must be accompanying explanations and examples followed by at least three sentences for each list item, formatted in Markdown.",
    #rule 7 
    "Total words in the articles is between 1500 to 2000 words.",
    #rule 1
    "The entire article must be formatted using Markdown syntax. \
        This includes using Markdown for headings, paragraphs, lists, bold and italic text, and hyperlinks. \
        Ensure that the formatting is consistent and follows standard Markdown conventions."
]

# %%
# prompt for fix the rules
prompt_revise_problem = [
    #rule 3
    "Modify the content to ensure it aligns with and accurately reflects the guidelines provided in the ```{instructions}```. \
        If any part of the article deviates from these instructions, revise it accordingly to meet the specified requirements. ",
    #rule 2
    "Remove any prefixes like 'H2' or 'Section' from the headings. For instance, change 'Section 1: Introduction to Biology' to 'Introduction to Biology' as per the outline.",
    #rule 4
    "Include at least one ordered (numbered) or unordered (bulleted) list in the article. Place this list under a heading formatted as either '##' for H2 headings or '###' for H3 headings. Use the Markdown format for lists, e.g., '* Bullet point' for unordered lists and '1. Item' for ordered lists.",
    #rule 5
    "Revise the article for a 6th-grade reading level. Simplify complex sentences, use more common words, and break down complicated concepts into easier-to-understand elements.",
    #rule 6
    "Ensure that each heading (formatted as '##' for H2 and '###' for H3) is followed by at least five sentences of explanatory text. No upper limit. Additionally, for each ordered or unordered list, provide explanations and examples for the listed items by at least two sentences of explanatory text. No upper limit. The lists should be in Markdown format.",
    #rule 7
    "Rewrite the article for a total word count between 1500 to 2000 words",
    #rule 1 
    f"""Convert the given article into Markdown format using all parts of <sample markdown>. 
        <sample markdown>

        This is some basic, sample markdown.
        # H1 for article
        ## H2. Second Heading


        * Unordered lists, and:
        1. One
        2. Two
        3. Three
        * More

        > Blockquote

        And **bold**, *italics*, and even *italics and later **bold***. Even ~~strikethrough~~. [A link](https://markdowntohtml.com) to somewhere.

        </sample markdown>"""
]

# %%
import random
level = random.choice(["top","middle","bottom"])
selected_funnel = funnel_list.get(level)
## pick a ramdom funnel

# %%
# read the outline from the website link
# need to change website link

website = f"""
https://www.invespcro.com/blog/e-commerce-abandonment-rates/
"""
prompt = f"""
create an outline based on the article link
```{website}```
"""
outline = get_completion(prompt)
print(outline)
# Out:
# I. Introduction
#     A. Definition of e-commerce abandonment rates
#     B. Importance of understanding and addressing abandonment rates in e-commerce
#
# II. Factors contributing to e-commerce abandonment rates
#     A. High shipping costs
#     B. Complicated checkout process
#     C. Lack of trust and security concerns
#     D. Limited payment options
#     E. Slow website loading speed
#
# III. Impact of e-commerce abandonment rates
#     A. Lost revenue and potential customers
#     B. Negative impact on brand reputation
#     C. Increased marketing costs to attract new customers
#
# IV. Strategies to reduce e-commerce abandonment rates
#     A. Offer free or discounted shipping
#     B. Simplify and streamline the checkout process
#     C. Enhance trust and security measures
#     D. Provide a variety of payment options
#     E. Optimize website loading speed
#
# V. Case studies and success stories
#     A. Examples of companies successfully reducing abandonment rates
#     B. Analysis of their strategies and outcomes
#
# VI. Conclusion
#     A. Recap of the importance of addressing e-commerce abandonment rates
#     B. Final thoughts on the future of e-commerce and abandonment rates.

# %%
# generate a clickable article title based on the provided outline and keyword.

prompt = f"""
Based on the outline, create a clickable article title that included the keyword and revise the outline to be used in my owm article based on revised title \
It shouldn't include any other brand service or product. 
keyword: ```{keyword}```
outline: ```{outline}```
"""
new_outline = get_completion(prompt)
print(new_outline)
# Out:
# Title: "Understanding and Addressing E-commerce Abandonment Rates: Strategies to Reduce Lost Revenue and Improve Brand Reputation"
#
# Revised Outline:
#
# I. Introduction
#     A. Definition of e-commerce abandonment rates
#     B. Importance of understanding and addressing abandonment rates in e-commerce
#
# II. Factors contributing to e-commerce abandonment rates
#     A. High shipping costs
#     B. Complicated checkout process
#     C. Lack of trust and security concerns
#     D. Limited payment options
#     E. Slow website loading speed
#
# III. Impact of e-commerce abandonment rates
#     A. Lost revenue and potential customers
#     B. Negative impact on brand reputation
#     C. Increased marketing costs to attract new customers
#
# IV. Strategies to reduce e-commerce abandonment rates
#     A. Offer free or discounted shipping
#     B. Simplify and streamline the checkout process
#     C. Enhance trust and security measures
#     D. Provide a variety of payment options
#     E. Optimize website loading speed
#
# V. Case studies and success stories
#     A. Examples of companies successfully reducing abandonment rates
#     B. Analysis of their strategies and outcomes
#
# VI. Conclusion
#     A. Recap of the importance of addressing e-commerce abandonment rates
#     B. Final thoughts on the future of e-commerce and abandonment rates.

# %%
# list the 10 related keywords

prompt = f"""
Based on the new outline, list some keywords that related the content and title in total of 10. Do not include the primpary keyword.
primary keyword: ```{keyword}```
outline: ```{new_outline}```
"""
other_keywords = get_completion(prompt)
print(other_keywords)
# Out:
# 1. E-commerce abandonment rates
# 2. Lost revenue
# 3. Brand reputation
# 4. Shipping costs
# 5. Checkout process
# 6. Trust and security concerns
# 7. Payment options
# 8. Website loading speed
# 9. Strategies to reduce abandonment rates
# 10. Case studies and success stories

# %%
instructions = f"""
Rewrite this title. Write the article readable for people in 6th grade. Use the headings and subheadings but use different words. \
Do not use the brands from the outline, use my brands from the XML <internal links>. \
Once you've used an internal link, do not use that internal link again. \
Take the <avatar> and write an article specifically for that person. Your tone should match the needs of the <avatar>. Do not mention the <avatar>. \
Do not mention other companies or brands, but focus more on educational or informative content. \
Write with a huge degree of creativity and informative burstiness. Try to include <keywords> as much as possible. \
Naturally add the primary keywords and other keywords into articles.  Explain nouns or ideas with examples and detailed explanations. \
Do not  mention any brand, services, or products. It is informative content. Create pictures to explain the ideas. \
Include all of the following HTML formatting at least once:

<sample markdown>

This is some basic, sample markdown.
# H1 for article
## H2. Second Heading


 * Unordered lists, and:
  1. One
  2. Two
  3. Three
 * More

> Blockquote

And **bold**, *italics*, and even *italics and later **bold***. Even ~~strikethrough~~. [A link](https://markdowntohtml.com) to somewhere.

</sample markdown>

Use all parts of <sample markdown>. Use the <outline> with the Focus keyword . Articles should include the h1, h2, h3 font size. where H1 is used for main title of the article and include the Focus keyword in <outline>. H2 are headings that break up the main sections of your content, add most keywords here, plan on around 3-5 of these H2s in 1000 words article. H3 are break up and list individual points in the main sections, in the form of numbered lists or clarifying sections to an H2 heading, for <keywords>

Firstly, write an introduction, with one paragraph, and an unordered list summarizing the entire article

Secondly, write the first half of the main part of the content, write at least 5 paragraphs.

Thirdly, write the second half of the main part of the content, write at least 3 paragraphs

Finally, write the conclusion, and include some links to other similar blogs at the bottom, write one paragraph.


<outline>

Focus keyword: ```{keyword}```

title and outline: ```{new_outline}```

</outline>

<avatar>

funnel: ```{selected_funnel}```

</avatar>

<keywords>

```{other_keywords}```

</keywords>

<internal links>

http://help.abconvert.io/en/
https://abconvert.io/
https://help.abconvert.io/
https://help.abconvert.io/cdn-cgi/l/email-protection
https://help.abconvert.io/en/
https://help.abconvert.io/en/articles/7991764-how-does-abconvert-work
https://help.abconvert.io/en/articles/7992482-how-to-run-price-test-only-on-new-customer
https://help.abconvert.io/en/articles/7994393-how-abconvert-analytics-works
https://help.abconvert.io/en/articles/8517478-how-to-start-a-url-redirect-test
https://help.abconvert.io/en/articles/8522853-how-to-test-product-price-shipping-at-the-same-time
https://help.abconvert.io/en/articles/8540376-how-to-find-product-using-advanced-search
https://help.abconvert.io/en/articles/8663230-how-to-set-up-utm-filter-for-price-test
https://help.abconvert.io/en/articles/8663287-how-to-end-test-safely-on-recharge-subscription-products
https://help.abconvert.io/en/articles/8676035-how-to-start-a-price-test
https://help.abconvert.io/en/articles/8726911-how-to-manage-duplicate-product
https://help.abconvert.io/en/articles/8730805-how-to-run-a-price-test-only-in-the-selected-countries
https://help.abconvert.io/en/articles/8735286-how-to-sync-inventory-for-your-test-products
https://help.abconvert.io/en/collections/3907966-shipping-rate-test
https://help.abconvert.io/en/collections/4080621-onboarding
https://help.abconvert.io/en/collections/4080626-advanced-topic
https://www.abconvert.io/
https://www.abconvert.io/abconvert-vs-intelligems
https://www.abconvert.io/blog
https://www.abconvert.io/blog/beginners-guide-to-a-b-testing
https://www.abconvert.io/blog/enhancing-e-commerce-success-a-comprehensive-guide-to-a-b-testing-for-conversion-rate-optimization
https://www.abconvert.io/blog/glossary-a-b-testing-essentials-for-e-commerce
https://www.abconvert.io/blog/mastering-price-testing-in-e-commerce-with-the-ice-framework
https://www.abconvert.io/blog/price-test-basics-how-to-optimize-your-e-commerce-store
https://www.abconvert.io/blog/the-art-of-price-testing-key-to-maximizing-store-profits
https://www.abconvert.io/blog/the-psychology-of-online-shopping-understanding-consumer-behavior
https://www.abconvert.io/blog/the-ultimate-guide-to-optimizing-your-shopify-store-with-abconvert
https://www.abconvert.io/blog/understanding-split-testing-a-comparative-look-with-a-b-testing
https://www.abconvert.io/blog/why-black-friday-is-the-best-day-for-price-testing
https://www.abconvert.io/contact-us
https://www.abconvert.io/features
https://www.abconvert.io/pricing
https://www.abconvert.io/privacy-policy
https://www.abconvert.io/why-a-b-test

</internal links>

"""

# %%
# creating the article with instructions

prompt = f"""
create the whole article follow by instructions. 
```{instructions}```
"""
article = get_completion(prompt)
print(article)
# Out:
# Understanding and Reducing E-commerce Abandonment Rates: Tips to Improve Your Online Store's Success
#
# Introduction:
# In the world of online shopping, e-commerce abandonment rates can have a significant impact on a business's success. But what exactly are abandonment rates, and why is it crucial to address them? In this article, we will explore the factors contributing to abandonment rates, their impact on revenue and brand reputation, and strategies to reduce them. Whether you're a business owner or a marketing professional, understanding and addressing abandonment rates is essential for optimizing your online store's conversion rates.
#
# Factors Contributing to E-commerce Abandonment Rates:
# 1. High Shipping Costs:
# One of the primary reasons customers abandon their online shopping carts is due to high shipping costs. When the cost of shipping outweighs the perceived value of the products, customers are more likely to abandon their purchase. Offering free or discounted shipping can help reduce abandonment rates and encourage customers to complete their transactions.
#
# 2. Complicated Checkout Process:
# A complicated and lengthy checkout process can frustrate customers and lead to cart abandonment. Simplifying and streamlining the checkout process by minimizing the number of steps and required information can significantly improve conversion rates. By making it easy for customers to complete their purchase, you can reduce abandonment rates and increase sales.
#
# 3. Lack of Trust and Security Concerns:
# In the digital age, trust and security are paramount for online shoppers. If customers feel uncertain about the safety of their personal information or the legitimacy of the website, they are more likely to abandon their carts. Enhancing trust and security measures, such as implementing secure payment gateways and displaying trust badges, can help alleviate these concerns and increase customer confidence.
#
# 4. Limited Payment Options:
# Customers have different preferences when it comes to payment methods. If an online store offers limited payment options that don't align with customers' preferences, they may choose to abandon their purchase. Providing a variety of payment options, such as credit cards, PayPal, and digital wallets, can cater to different customer preferences and reduce abandonment rates.
#
# 5. Slow Website Loading Speed:
# In today's fast-paced world, customers expect websites to load quickly. If a website takes too long to load, customers may become impatient and abandon their carts. Optimizing website loading speed by compressing images, minimizing plugins, and utilizing caching techniques can significantly improve the user experience and reduce abandonment rates.
#
# Impact of E-commerce Abandonment Rates:
# 1. Lost Revenue and Potential Customers:
# When customers abandon their shopping carts, it directly translates to lost revenue for the business. Additionally, these potential customers may never return, resulting in missed opportunities for future sales. By addressing abandonment rates, businesses can recover lost revenue and retain potential customers.
#
# 2. Negative Impact on Brand Reputation:
# High abandonment rates can negatively impact a brand's reputation. Customers may perceive a business with high abandonment rates as untrustworthy or unreliable. This negative perception can deter potential customers from making purchases and harm the overall brand image. By reducing abandonment rates, businesses can improve their brand reputation and attract more customers.
#
# 3. Increased Marketing Costs:
# To compensate for lost revenue and attract new customers, businesses often need to invest more in marketing efforts. This can include running targeted advertising campaigns, offering discounts or promotions, or implementing loyalty programs. By reducing abandonment rates, businesses can minimize the need for extensive marketing efforts and allocate resources more efficiently.
#
# Strategies to Reduce E-commerce Abandonment Rates:
# 1. Offer Free or Discounted Shipping:
# Providing free or discounted shipping can be a powerful incentive for customers to complete their purchases. By absorbing or reducing shipping costs, businesses can eliminate a significant barrier to purchase and reduce abandonment rates.
#
# 2. Simplify and Streamline the Checkout Process:
# A user-friendly and streamlined checkout process can significantly improve conversion rates. Minimize the number of steps required to complete a purchase and only ask for essential information. By making the checkout process quick and hassle-free, businesses can reduce abandonment rates and increase customer satisfaction.
#
# 3. Enhance Trust and Security Measures:
# Building trust with customers is crucial for reducing abandonment rates. Implement secure payment gateways, display trust badges, and provide clear privacy policies to instill confidence in customers. By prioritizing trust and security, businesses can alleviate customer concerns and increase conversion rates.
#
# 4. Provide a Variety of Payment Options:
# Catering to customers' payment preferences is essential for reducing abandonment rates. Offer a wide range of payment options, including credit cards, PayPal, and digital wallets, to accommodate different customer preferences. By providing flexibility in payment methods, businesses can increase the likelihood of customers completing their purchases.
#
# 5. Optimize Website Loading Speed:
# A fast-loading website is vital for a positive user experience. Optimize website loading speed by optimizing images, minimizing plugins, and utilizing caching techniques. By ensuring a seamless browsing experience, businesses can reduce abandonment rates and improve customer satisfaction.
#
# Conclusion:
# Understanding and addressing e-commerce abandonment rates is crucial for the success of online stores. By implementing strategies to reduce abandonment rates, such as offering free shipping, simplifying the checkout process, enhancing trust and security measures, providing a variety of payment options, and optimizing website loading speed, businesses can improve their conversion rates, retain customers, and enhance their brand reputation. Remember, every abandoned cart represents a missed opportunity, so take action to reduce abandonment rates and maximize your online store's success.
#
# For more insights and tips on optimizing your e-commerce store, check out these related blogs:
# - [Beginner's Guide to A/B Testing](https://www.abconvert.io/blog/beginners-guide-to-a-b-testing)
# - [Enhancing E-commerce Success: A Comprehensive Guide to A/B Testing for Conversion Rate Optimization](https://www.abconvert.io/blog/enhancing-e-commerce-success-a-comprehensive-guide-to-a-b-testing)
# - [Mastering Price Testing in E-commerce with the ICE Framework](https://www.abconvert.io/blog/mastering-price-testing-in-e-commerce-with-the-ice-framework)
#
# Remember, understanding and addressing abandonment rates is a continuous process, and staying informed about industry trends and best practices is essential for long-term success.

# %%
# Iterates through a list of rules for checking places in the article. 
# The code prompts the user to check if the article adheres to each rule, providing a detailed response. 
# If the response indicates a rule violation, the code prompts for article revision and repeats the checking process.
# Return the final revised version of the article after checking against all rules.

testing_text = article 
i = 0 # showcase the number of rule

for rule in checking_places:
    check_prompt = f"""
    Check the article against ```{rule} ```. Tell Yes or No. \
    Please provide a detailed response in one-line output indicating which an example in the article. \
    If you cannot find the example of the places in the article, please re-check the rule.

    outline: ```{new_outline}```
    article: ```{testing_text}```
    """

    start_time = time.time() # Record the start time

    while get_completion(check_prompt).startswith("No"):
        # Check the elapsed time
        elapsed_time = time.time() - start_time
        if elapsed_time > timeout_seconds:
            print(f"Time limit exceeded for rule: {rule}")
            break  # Break out of the loop if time limit exceeded

        regenerate_prompt = f"""
        ```{prompt_revise_problem[i]} ```. Revise the least places in the article and return the all article after revision at the end. 

        outline: ```{new_outline}```
        article: ```{testing_text}```
        """
        testing_text = get_completion(regenerate_prompt)
        
        check_prompt = f"""
        Check the article against ```{rule} ```. Tell Yes or No. \
        Please provide a detailed response in one-line output indicating which an example in the article. \
        If you cannot find the example of the places in the article, please re-check the rule.

        outline: ```{new_outline}```
        article: ```{testing_text}```
        """
    i = i+ 1

final_article = testing_text
print(final_article)
# Out:
# Time limit exceeded for rule: Each heading in the article must exactly match a corresponding point in the outline, which is formatted as a bulleted list.         Headings should not include any prefixes such as 'H2' or 'Section'. For instance, if the outline lists 'Introduction to Biology', the article must use 'Introduction to Biology' as the heading, not 'Section 1: Introduction to Biology'. If an article heading does not match the outline, provide an example of a non-compliant heading.
# Understanding and Reducing E-commerce Abandonment Rates: Tips to Improve Your Online Store's Success
#
# Introduction:
# In the world of online shopping, e-commerce abandonment rates can have a significant impact on a business's success. But what exactly are abandonment rates, and why is it crucial to address them? In this article, we will explore the factors contributing to abandonment rates, their impact on revenue and brand reputation, and strategies to reduce them. Whether you're a business owner or a marketing professional, understanding and addressing abandonment rates is essential for optimizing your online store's conversion rates.
#
# Factors Contributing to E-commerce Abandonment Rates:
# 1. High Shipping Costs:
# One of the primary reasons customers abandon their online shopping carts is due to high shipping costs. When the cost of shipping outweighs the perceived value of the products, customers are more likely to abandon their purchase. Offering free or discounted shipping can help reduce abandonment rates and encourage customers to complete their transactions.
#
# 2. Complicated Checkout Process:
# A complicated and lengthy checkout process can frustrate customers and lead to cart abandonment. Simplifying and streamlining the checkout process by minimizing the number of steps and required information can significantly improve conversion rates. By making it easy for customers to complete their purchase, you can reduce abandonment rates and increase sales.
#
# 3. Lack of Trust and Security Concerns:
# In the digital age, trust and security are paramount for online shoppers. If customers feel uncertain about the safety of their personal information or the legitimacy of the website, they are more likely to abandon their carts. Enhancing trust and security measures, such as implementing secure payment gateways and displaying trust badges, can help alleviate these concerns and increase customer confidence.
#
# 4. Limited Payment Options:
# Customers have different preferences when it comes to payment methods. If an online store offers limited payment options that don't align with customers' preferences, they may choose to abandon their purchase. Providing a variety of payment options, such as credit cards, PayPal, and digital wallets, can cater to different customer preferences and reduce abandonment rates.
#
# 5. Slow Website Loading Speed:
# In today's fast-paced world, customers expect websites to load quickly. If a website takes too long to load, customers may become impatient and abandon their carts. Optimizing website loading speed by compressing images, minimizing plugins, and utilizing caching techniques can significantly improve the user experience and reduce abandonment rates.
#
# Impact of E-commerce Abandonment Rates:
# 1. Lost Revenue and Potential Customers:
# When customers abandon their shopping carts, it directly translates to lost revenue for the business. Additionally, these potential customers may never return, resulting in missed opportunities for future sales. By addressing abandonment rates, businesses can recover lost revenue and retain potential customers.
#
# 2. Negative Impact on Brand Reputation:
# High abandonment rates can negatively impact a brand's reputation. Customers may perceive a business with high abandonment rates as untrustworthy or unreliable. This negative perception can deter potential customers from making purchases and harm the overall brand image. By reducing abandonment rates, businesses can improve their brand reputation and attract more customers.
#
# 3. Increased Marketing Costs:
# To compensate for lost revenue and attract new customers, businesses often need to invest more in marketing efforts. This can include running targeted advertising campaigns, offering discounts or promotions, or implementing loyalty programs. By reducing abandonment rates, businesses can minimize the need for extensive marketing efforts and allocate resources more efficiently.
#
# Strategies to Reduce E-commerce Abandonment Rates:
# 1. Offer Free or Discounted Shipping:
# Providing free or discounted shipping can be a powerful incentive for customers to complete their purchases. By absorbing or reducing shipping costs, businesses can eliminate a significant barrier to purchase and reduce abandonment rates.
#
# 2. Simplify and Streamline the Checkout Process:
# A user-friendly and streamlined checkout process can significantly improve conversion rates. Minimize the number of steps required to complete a purchase and only ask for essential information. By making the checkout process quick and hassle-free, businesses can reduce abandonment rates and increase customer satisfaction.
#
# 3. Enhance Trust and Security Measures:
# Building trust with customers is crucial for reducing abandonment rates. Implement secure payment gateways, display trust badges, and provide clear privacy policies to instill confidence in customers. By prioritizing trust and security, businesses can alleviate customer concerns and increase conversion rates.
#
# 4. Provide a Variety of Payment Options:
# Catering to customers' payment preferences is essential for reducing abandonment rates. Offer a wide range of payment options, including credit cards, PayPal, and digital wallets, to accommodate different customer preferences. By providing flexibility in payment methods, businesses can increase the likelihood of customers completing their purchases.
#
# 5. Optimize Website Loading Speed:
# A fast-loading website is vital for a positive user experience. Optimize website loading speed by optimizing images, minimizing plugins, and utilizing caching techniques. By ensuring a seamless browsing experience, businesses can reduce abandonment rates and improve customer satisfaction.
#
# Conclusion:
# Understanding and addressing e-commerce abandonment rates is crucial for the success of online stores. By implementing strategies to reduce abandonment rates, such as offering free shipping, simplifying the checkout process, enhancing trust and security measures, providing a variety of payment options, and optimizing website loading speed, businesses can improve their conversion rates, retain customers, and enhance their brand reputation. Remember, every abandoned cart represents a missed opportunity, so take action to reduce abandonment rates and maximize your online store's success.
#
# For more insights and tips on optimizing your e-commerce store, check out these related blogs:
# - Beginner's Guide to A/B Testing
# - Enhancing E-commerce Success: A Comprehensive Guide to A/B Testing for Conversion Rate Optimization
# - Mastering Price Testing in E-commerce with the ICE Framework
#
# Remember, understanding and addressing abandonment rates is a continuous process, and staying informed about industry trends and best practices is essential for long-term success.

# %% [markdown]
# test

# %%
def html_get_completion(prompt):
    messages = [{"role": "user", "content": prompt}]
    response = client.chat.completions.create(
        messages=messages,
        temperature=0,
        model="gpt-3.5-turbo"
    )
    return response.choices[0].message.content
    
    # Manually revise or post-process the initial article
    
    # Optional: Send revised version back to OpenAI for further improvement
    # revised_response = openai.Completion.create(
    #     engine="davinci-codex",
    #     prompt=initial_article,
    #     max_tokens=500,
    #     format="markdown"
    # )
    # revised_article = revised_response['choices'][0]['text']

# %%
if "```" not in test_article:
    print("Revised text is not in Markdown format.")
# Out:
# Revised text is not in Markdown format.

# %%
sample_markdown = f"""
        This is some basic, sample markdown. \
        # H1 for article 
        ## H2. Second Heading \
        * Unordered lists, and:
        1. One
        2. Two
        3. Three
        * More \
        > Blockquote \
        And **bold**, *italics*, and even *italics and later **bold***. Even ~~strikethrough~~. [A link](https://markdowntohtml.com) to somewhere.

"""

prompt = f"""
Convert the given article into Markdown format to define headings (h1, h2, h3), unordered lists, and ordered lists.

Article to be formatted: ```{final_article}```
"""
test_article = html_get_completion(prompt)
print(test_article)
# Out:
# # Understanding and Addressing E-commerce Abandonment Rates: Strategies to Reduce Lost Revenue and Improve Brand Reputation
#
# ## Introduction:
# E-commerce abandonment rates can have a significant impact on your online store's success. When customers abandon their shopping carts without completing a purchase, it leads to lost revenue and can harm your brand reputation. In this article, we will explore the factors contributing to abandonment rates and provide strategies to reduce them, ultimately improving your store's performance.
#
# ## Factors Contributing to E-commerce Abandonment Rates:
# 1. High Shipping Costs:
#    - Customers are often deterred by high shipping costs. Offering free or discounted shipping can incentivize them to complete their purchase.
#
# 2. Complicated Checkout Process:
#    - A complicated checkout process can frustrate customers and lead to abandonment. Simplifying and streamlining the process by removing unnecessary steps can improve conversion rates.
#
# 3. Lack of Trust and Security Concerns:
#    - Customers need to feel secure when making online purchases. Enhancing trust and security measures, such as displaying trust badges and using secure payment gateways, can alleviate their concerns.
#
# 4. Limited Payment Options:
#    - Customers have different preferences when it comes to payment methods. Providing a variety of payment options, such as credit cards, PayPal, and digital wallets, can cater to their needs and reduce abandonment rates.
#
# 5. Slow Website Loading Speed:
#    - A slow-loading website can test the patience of customers and drive them away. Optimizing your website's loading speed by compressing images and minimizing code can create a seamless shopping experience.
#
# ## Impact of E-commerce Abandonment Rates:
# 1. Lost Revenue and Potential Customers:
#    - Every abandoned cart represents a missed opportunity for revenue. By reducing abandonment rates, you can increase your sales and attract more customers.
#
# 2. Negative Impact on Brand Reputation:
#    - Customers may perceive a high abandonment rate as a sign of poor customer experience or unreliable service. This can damage your brand reputation and make it harder to attract new customers.
#
# 3. Increased Marketing Costs:
#    - To compensate for lost revenue, you may need to invest more in marketing efforts to acquire new customers. By addressing abandonment rates, you can reduce the need for excessive marketing expenses.
#
# ## Strategies to Reduce E-commerce Abandonment Rates:
# 1. Offer Free or Discounted Shipping:
#    - Providing free or discounted shipping can be a powerful incentive for customers to complete their purchase. Highlight this offer prominently on your website to attract their attention.
#
# 2. Simplify and Streamline the Checkout Process:
#    - Make the checkout process as simple and straightforward as possible. Remove unnecessary steps and only ask for essential information to minimize friction and increase conversion rates.
#
# 3. Enhance Trust and Security Measures:
#    - Display trust badges, security certifications, and customer reviews to build trust with your customers. Assure them that their personal and financial information is safe and secure.
#
# 4. Provide a Variety of Payment Options:
#    - Offer a range of payment options to accommodate different customer preferences. This includes credit cards, PayPal, and other popular digital payment methods.
#
# 5. Optimize Website Loading Speed:
#    - Ensure that your website loads quickly to provide a seamless shopping experience. Compress images, minimize code, and leverage caching techniques to improve loading times.
#
# ## Case Studies and Success Stories:
# - Explore examples of companies that have successfully reduced abandonment rates. Analyze their strategies and outcomes to gain insights into effective approaches for your own online store.
#
# ## Conclusion:
# Understanding and addressing e-commerce abandonment rates is crucial for the success of your online store. By implementing strategies to reduce abandonment rates, such as offering free shipping, simplifying the checkout process, and enhancing trust and security measures, you can improve your store's performance and increase revenue. Remember to optimize your website's loading speed and provide a variety of payment options to cater to customer preferences. With these strategies in place, you can create a positive shopping experience that encourages customers to complete their purchases.
#
# For more informative articles on e-commerce and optimization strategies, check out these related blogs:
# - Beginner's Guide to A/B Testing
# - Enhancing E-commerce Success: A Comprehensive Guide to A/B Testing for Conversion Rate Optimization
# - The Ultimate Guide to Optimizing Your Shopify Store with ABConvert

# %%
import re
def is_markdown(text):
    # Check for the presence of common Markdown elements
    markdown_pattern = re.compile(r'(#|##|###|\*|1\.)')
    return bool(re.search(markdown_pattern, text))

# %%
print(is_markdown(final_article))
# Out:
# True

# %%
testing_text = test_article 
i = 0 # showcase the number of rule

for rule in checking_places:
    check_prompt = f"""
    Check the article against ```{rule} ```. Tell Yes or No. \
    Please provide a detailed response in one-line output indicating which an example in the article. \
    If you cannot find the example of the places in the article, please re-check the rule.

    outline: ```{new_outline}```
    article: ```{testing_text}```
    """

    start_time = time.time() # Record the start time

    while get_completion(check_prompt).startswith("No"):
        # Check the elapsed time
        elapsed_time = time.time() - start_time
        if elapsed_time > timeout_seconds:
            print(f"Time limit exceeded for rule: {rule}")
            break  # Break out of the loop if time limit exceeded

        regenerate_prompt = f"""
        ```{prompt_revise_problem[i]} ```. Revise the least places in the article and return the all article after revision at the end. 

        outline: ```{new_outline}```
        article: ```{testing_text}```
        """
        testing_text = html_get_completion(regenerate_prompt)
        
        check_prompt = f"""
        Check the article against ```{rule} ```. Tell Yes or No. \
        Please provide a detailed response in one-line output indicating which an example in the article. \
        If you cannot find the example of the places in the article, please re-check the rule.

        outline: ```{new_outline}```
        article: ```{testing_text}```
        """
    i = i+ 1

test_final_article = testing_text
print(test_final_article)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18732/1969842527.py in <module>
#      22
#      23         regenerate_prompt = f"""
# ---> 24         ```{prompt_revise_problem[i]} ```. Revise the least places in the article and return the all article after revision at the end.
#      25
#      26         outline: ```{new_outline}```
#
# ~\AppData\Local\Temp/ipykernel_18732/1969842527.py in <module>
#      22
#      23         regenerate_prompt = f"""
# ---> 24         ```{prompt_revise_problem[i]} ```. Revise the least places in the article and return the all article after revision at the end.
#      25
#      26         outline: ```{new_outline}```
#
# _pydevd_bundle/pydevd_cython.pyx in _pydevd_bundle.pydevd_cython.SafeCallWrapper.__call__()
#
# _pydevd_bundle/pydevd_cython.pyx in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# _pydevd_bundle/pydevd_cython.pyx in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# _pydevd_bundle/pydevd_cython.pyx in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# _pydevd_bundle/pydevd_cython.pyx in _pydevd_bundle.pydevd_cython.PyDBFrame.do_wait_suspend()
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\debugpy\_vendored\pydevd\pydevd.py in do_wait_suspend(self, thread, frame, event, arg, exception_type)
#    1947
#    1948             with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, stop_reason):
# -> 1949                 keep_suspended = self._do_wait_suspend(thread, frame, event, arg, suspend_type, from_this_thread, frames_tracker)
#    1950
#    1951         frames_list = None
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\debugpy\_vendored\pydevd\pydevd.py in _do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread, frames_tracker)
#    1982
#    1983             self.process_internal_commands()
# -> 1984             time.sleep(0.01)
#    1985
#    1986         self.cancel_async_evaluation(get_current_thread_id(thread), str(id(frame)))
#
# KeyboardInterrupt:

# %% [markdown]
# /test

# %%
# create a short abstract of article within 500 words due to the prompt limit in image generation

prompt = f"""
do the overview of the artciel within 500 characters.

article: ```{final_article}```
"""

abstract= get_completion(prompt)
print(abstract)
# Out:
# This article discusses the importance of understanding and addressing e-commerce abandonment rates. It highlights factors contributing to abandonment rates, such as high shipping costs, complicated checkout processes, lack of trust and security concerns, limited payment options, and slow website loading speed. The article also explains the impact of abandonment rates on revenue, brand reputation, and marketing costs. Strategies to reduce abandonment rates are provided, including offering free or discounted shipping, simplifying the checkout process, enhancing trust and security measures, providing a variety of payment options, and optimizing website loading speed. The article concludes by emphasizing the need to implement these strategies to improve store performance and increase revenue.

# %%
# function to create blog picture
# change testing_text to article
def generate_blog_picture(abstract):

    # Define the prompt
    prompt = f"Create a blog picture in English based on the following blog content: '{abstract}'."

    # Specify other parameters
    n = 1  # Number of images to generate
    size = "1792x1024"  # Max image size
    quality = "standard" # set image quality

    # Generate image using OpenAI API
    response = client.images.generate(
        model="dall-e-3",  # Check for the latest model name
        prompt=prompt,
        n=n,
        size=size,
        quality= quality
    )

    # Extract the generated image URL
    image_url = response.data[0].url

    return image_url

# %%
picture_link = generate_blog_picture(abstract)

# %%
# create meta data in JSON
total_finish_time = time.time()
duration = round((total_finish_time - total_start_time) / 60,2)
prompt = f"""
Create a JSON data structure designed to collect information on titles, keywords, and funnels. \
The structure should include keys named 'title', 'blog picture link', 'primary keyword', 'other_keywords', 'funnel', 'minutes' ,'date',and 'reference'. \
Each 'title' should be a string representing the title in the outline, \
    'primary keyword' should be the primary keyword, \
    'blog picture link' should be the blog picture link, \
    'other keyword' should be the other keyword, \
    'funnel' should be one of the level in the funnel (top, middle,or bottom), \
    'minutes' should be the duration of the program, \
    'date' is the today's date in the format of MM-DD-YYYY, \
    and 'reference' should be the website link. \


outline: ```{new_outline}```
blog picture link: ```{picture_link}```
primary keyword: ```{keyword}```
other keyword: ```{other_keywords}```
funnel: ```{level}```
minutes = ```{duration}```
date ```{today_date}```
reference: ```{website}```
"""

artilce_meta= get_completion(prompt)
print(artilce_meta)
# Out:
# {
#   "title": "Understanding and Addressing E-commerce Abandonment Rates: Strategies to Reduce Lost Revenue and Improve Brand Reputation",
#   "blog picture link": "https://oaidalleapiprodscus.blob.core.windows.net/private/org-XsbS2SJ0y6rGde6yJBagVpWT/user-A4WpGwDF6YUHHn0rJoaDsjhh/img-Hh07dhNEgv0LmfM6nIqfXQix.png?st=2024-01-23T07%3A10%3A26Z&se=2024-01-23T09%3A10%3A26Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-01-22T22%3A03%3A38Z&ske=2024-01-23T22%3A03%3A38Z&sks=b&skv=2021-08-06&sig=ez3QhXjP879jbQEIn74PSKS5D9WMbKHFSub%2BvKiHoVk%3D",
#   "primary keyword": "abandonment rate",
#   "other_keywords": [
#     "E-commerce abandonment rates",
#     "Lost revenue",
#     "Brand reputation",
#     "Shipping costs",
#     "Checkout process",
#     "Trust and security concerns",
#     "Payment options",
#     "Website loading speed",
#     "Strategies to reduce abandonment rates",
#     "Case studies and success stories"
#   ],
#   "funnel": "top",
#   "minutes": 3.49,
#   "date": "2024-01-23",
#   "reference": "https://www.invespcro.com/blog/e-commerce-abandonment-rates/"
# }

# %% [markdown]
# # Create the blog picture

# %%
back_up_checking_places = [
    #rule 1
    "The article is in markdowm format", 
    #rule 2
    "Each heading matches exactly with the corresponding point in the outline, without any unrelated prefixes like 'H2' or 'Section'. \
    The outline is formatted as a bulleted list, with each point being a potential section heading. \
    Please ensure that the text for each heading in the document is followed by the outline. \
    For example, if the outline has 'Introduction to Biology', the heading should also be 'Introduction to Biology' and not 'Section 1: Introduction to Biology'.\
    Check the above rule description carefully and provide one incorrect heading if the article against the rule.",
    #rule 3
    "All article content must be generated based on the instructions provided in the following format: ```{instructions}```. Ensure that the article strictly adheres to these guidelines.",
    #rule 4
    "include at least one ordered list or unorder list, representing in '* Unordered lists, and: 1. One 2. Two 3. Three * More' in markdown format, under a H2 heading or a H3 heading content",
    #rule 5
    "The article is readable for people in 6th grade.",
    #rule 6
    "Each heading, represetning in '## H2 heading ### H3 heading' has more than three sentences. Ordered or unorder lists, representing in '* Unordered lists, and: 1. One 2. Two 3. Three * More' in markdown format, mast have the explination has the explainations and exmaples "
]
